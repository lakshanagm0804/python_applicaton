# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\boyal\OneDrive\Documents\sales_data_sample.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05-07-2003 00:00  Shipped       2         5     2003  ...
# 2  07-01-2003 00:00  Shipped       3         7     2003  ...
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10-10-2003 00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.drop(['ADDRESSLINE2'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df['STATE']
# Out:
# 0        NY
# 1       NaN
# 2       NaN
# 3        CA
# 4        CA
#        ...
# 2818    NaN
# 2819    NaN
# 2820    NaN
# 2821    NaN
# 2822     MA
# Name: STATE, Length: 2823, dtype: object

# %%
df.update(df[['STATE', 'TERRITORY', 'POSTALCODE']].fillna(df.mode().iloc[0]))

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE                  0
# POSTALCODE             0
# COUNTRY                0
# TERRITORY              0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.drop(['ADDRESSLINE2'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1        NaT  Shipped       2         5     2003  ...
# 2        NaT  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4        NaT  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
print(df[df['ORDERDATE'].isna()]['ORDERDATE'])
# Out:
# 1      NaT
# 2      NaT
# 4      NaT
# 6      NaT
# 8      NaT
#         ..
# 2813   NaT
# 2816   NaT
# 2818   NaT
# 2820   NaT
# 2822   NaT
# Name: ORDERDATE, Length: 1305, dtype: datetime64[ns]

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'], errors='coerce')

# %%
most_common_date = df['ORDERDATE'].mode()[0]  # Get the most common date
df['ORDERDATE'] = df['ORDERDATE'].fillna(most_common_date)  # Fill NaT values

# %%
print(df['ORDERDATE'].isna().sum())  # Should be 0
print(df['ORDERDATE'].head(10))  # Check the first few values
# Out:
# 0
# 0   2003-02-24
# 1   2003-11-14
# 2   2003-11-14
# 3   2003-08-25
# 4   2003-11-14
# 5   2003-10-28
# 6   2003-11-14
# 7   2003-11-18
# 8   2003-11-14
# 9   2004-01-15
# Name: ORDERDATE, dtype: datetime64[ns]

# %%
print(df.describe())  # Summary stats for numerical columns
print(df[['STATE', 'TERRITORY', 'PRODUCTLINE']].describe())  # Summary for categorical data
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
import matplotlib.pyplot as plt
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'], format='%d-%m-%Y %H:%M', errors='coerce')
df.groupby('ORDERDATE')['SALES'].sum().plot(figsize=(12,6), title="Sales Over Time")
plt.show()

# %%
print(df.mode().iloc[0])
# Out:
# ORDERNUMBER                         10106
# QUANTITYORDERED                      34.0
# PRICEEACH                           100.0
# ORDERLINENUMBER                       1.0
# SALES                              3003.0
# ORDERDATE             2003-11-14 00:00:00
# STATUS                            Shipped
# QTR_ID                                4.0
# MONTH_ID                             11.0
# YEAR_ID                            2004.0
# PRODUCTLINE                  Classic Cars
# MSRP                                118.0
# PRODUCTCODE                      S18_3232
# CUSTOMERNAME        Euro Shopping Channel
# PHONE                      (91) 555 94 44
# ADDRESSLINE1           C/ Moralzarzal, 86
# ADDRESSLINE2                      Level 3
# CITY                               Madrid
# STATE                                  CA
# POSTALCODE                          28034
# COUNTRY                               USA
# TERRITORY                            EMEA
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker  # Import ticker for formatting

top_products = df.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
ax = top_products.plot(kind='bar', title="Top Performing Product Lines")

plt.xticks(rotation=45)
plt.ylabel("Sales Amount")  

# Format y-axis to show whole numbers
ax.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}')) 

plt.show()

# %%
df['MONTH'] = df['ORDERDATE'].dt.month
df.groupby('MONTH')['SALES'].sum().plot(kind='line', marker='o', title="Monthly Sales Trends")
plt.show()
